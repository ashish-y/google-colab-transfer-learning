# %% [markdown]
# <a href="https://colab.research.google.com/github/ashish-y/google-colab-transfer-learning/blob/main/EfficientNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile
file = "dataset.zip"

with ZipFile(file, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
#os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"
import tensorflow as tf 
print(tf.__version__);
if tf.test.gpu_device_name(): 
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
   print("Please install GPU version of TF")
import tensorflow.keras as keras
keras.__version__
# Out:
# 2.3.0
# Default GPU Device:/device:GPU:0
# '2.4.0'

# %%
import tensorflow.keras

# %%
#import tfkeras as ef
import tensorflow.keras.applications.efficientnet as ef
#import tensorflow.keras.applications.efficientnet as ef

# %%
input_size = 150

# %%
base_model =  ef.EfficientNetB7(input_shape=(input_size, input_size, 3), weights='imagenet',include_top=False)
#for layer in base_model.layers:
#    layer.trainable = False
x = tensorflow.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tensorflow.keras.layers.Dense(3, activation='softmax')(x)
Model = tensorflow.keras.models.Model(inputs=[base_model.input], outputs=[output])

# %%
Model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# rescaling_3 (Rescaling)         (None, 150, 150, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# normalization_3 (Normalization) (None, 150, 150, 3)  7           rescaling_3[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 151, 151, 3)  0           normalization_3[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 75, 75, 64)   1728        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 75, 75, 64)   256         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 75, 75, 64)   0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 75, 75, 64)   576         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 75, 75, 64)   256         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 75, 75, 64)   0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 64)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 64)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 16)     1040        block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 64)     1088        block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 75, 75, 64)   0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 75, 75, 32)   2048        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 75, 75, 32)   128         block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 75, 75, 32)   288         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 75, 75, 32)   128         block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 75, 75, 32)   0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 32)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 75, 75, 32)   0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 75, 75, 32)   1024        block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 75, 75, 32)   128         block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 75, 75, 32)   0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 75, 75, 32)   0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 75, 75, 32)   288         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 75, 75, 32)   128         block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 75, 75, 32)   0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 32)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 75, 75, 32)   0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 75, 75, 32)   1024        block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 75, 75, 32)   128         block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (Dropout)          (None, 75, 75, 32)   0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 75, 75, 32)   0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block1d_dwconv (DepthwiseConv2D (None, 75, 75, 32)   288         block1c_add[0][0]
# __________________________________________________________________________________________________
# block1d_bn (BatchNormalization) (None, 75, 75, 32)   128         block1d_dwconv[0][0]
# __________________________________________________________________________________________________
# block1d_activation (Activation) (None, 75, 75, 32)   0           block1d_bn[0][0]
# __________________________________________________________________________________________________
# block1d_se_squeeze (GlobalAvera (None, 32)           0           block1d_activation[0][0]
# __________________________________________________________________________________________________
# block1d_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1d_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1d_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1d_se_excite (Multiply)    (None, 75, 75, 32)   0           block1d_activation[0][0]
#                                                                  block1d_se_expand[0][0]
# __________________________________________________________________________________________________
# block1d_project_conv (Conv2D)   (None, 75, 75, 32)   1024        block1d_se_excite[0][0]
# __________________________________________________________________________________________________
# block1d_project_bn (BatchNormal (None, 75, 75, 32)   128         block1d_project_conv[0][0]
# __________________________________________________________________________________________________
# block1d_drop (Dropout)          (None, 75, 75, 32)   0           block1d_project_bn[0][0]
# __________________________________________________________________________________________________
# block1d_add (Add)               (None, 75, 75, 32)   0           block1d_drop[0][0]
#                                                                  block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 75, 75, 192)  6144        block1d_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 75, 75, 192)  768         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 75, 75, 192)  0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 77, 77, 192)  0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 38, 38, 192)  1728        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 38, 38, 192)  768         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 38, 38, 192)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 192)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 38, 38, 192)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 38, 38, 48)   9216        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 38, 38, 48)   192         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 38, 38, 288)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 38, 38, 288)  2592        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 38, 38, 288)  1152        block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 38, 38, 288)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 288)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 38, 38, 288)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 38, 38, 48)   192         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 38, 38, 48)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 38, 38, 48)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 38, 38, 288)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 38, 38, 288)  2592        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 38, 38, 288)  1152        block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 38, 38, 288)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 288)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 38, 38, 288)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 38, 38, 48)   192         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 38, 38, 48)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 38, 38, 48)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 38, 38, 288)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 38, 38, 288)  2592        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 38, 38, 288)  1152        block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 38, 38, 288)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 288)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 38, 38, 288)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 38, 38, 48)   192         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 38, 38, 48)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 38, 38, 48)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 38, 38, 288)  0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 38, 38, 288)  2592        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 38, 38, 288)  1152        block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 38, 38, 288)  0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 288)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 38, 38, 288)  0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 38, 38, 48)   192         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (Dropout)          (None, 38, 38, 48)   0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 38, 38, 48)   0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block2e_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block2f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2f_expand_activation (Acti (None, 38, 38, 288)  0           block2f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2f_dwconv (DepthwiseConv2D (None, 38, 38, 288)  2592        block2f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2f_bn (BatchNormalization) (None, 38, 38, 288)  1152        block2f_dwconv[0][0]
# __________________________________________________________________________________________________
# block2f_activation (Activation) (None, 38, 38, 288)  0           block2f_bn[0][0]
# __________________________________________________________________________________________________
# block2f_se_squeeze (GlobalAvera (None, 288)          0           block2f_activation[0][0]
# __________________________________________________________________________________________________
# block2f_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2f_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2f_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2f_se_excite (Multiply)    (None, 38, 38, 288)  0           block2f_activation[0][0]
#                                                                  block2f_se_expand[0][0]
# __________________________________________________________________________________________________
# block2f_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block2f_se_excite[0][0]
# __________________________________________________________________________________________________
# block2f_project_bn (BatchNormal (None, 38, 38, 48)   192         block2f_project_conv[0][0]
# __________________________________________________________________________________________________
# block2f_drop (Dropout)          (None, 38, 38, 48)   0           block2f_project_bn[0][0]
# __________________________________________________________________________________________________
# block2f_add (Add)               (None, 38, 38, 48)   0           block2f_drop[0][0]
#                                                                  block2e_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block2f_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block2g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2g_expand_activation (Acti (None, 38, 38, 288)  0           block2g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2g_dwconv (DepthwiseConv2D (None, 38, 38, 288)  2592        block2g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2g_bn (BatchNormalization) (None, 38, 38, 288)  1152        block2g_dwconv[0][0]
# __________________________________________________________________________________________________
# block2g_activation (Activation) (None, 38, 38, 288)  0           block2g_bn[0][0]
# __________________________________________________________________________________________________
# block2g_se_squeeze (GlobalAvera (None, 288)          0           block2g_activation[0][0]
# __________________________________________________________________________________________________
# block2g_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2g_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2g_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2g_se_excite (Multiply)    (None, 38, 38, 288)  0           block2g_activation[0][0]
#                                                                  block2g_se_expand[0][0]
# __________________________________________________________________________________________________
# block2g_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block2g_se_excite[0][0]
# __________________________________________________________________________________________________
# block2g_project_bn (BatchNormal (None, 38, 38, 48)   192         block2g_project_conv[0][0]
# __________________________________________________________________________________________________
# block2g_drop (Dropout)          (None, 38, 38, 48)   0           block2g_project_bn[0][0]
# __________________________________________________________________________________________________
# block2g_add (Add)               (None, 38, 38, 48)   0           block2g_drop[0][0]
#                                                                  block2f_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block2g_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 38, 38, 288)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 41, 41, 288)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 19, 19, 288)  7200        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 19, 19, 288)  1152        block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 19, 19, 288)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 288)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 19, 19, 288)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 19, 19, 80)   23040       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 19, 19, 80)   320         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 19, 19, 480)  38400       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 19, 19, 480)  1920        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 19, 19, 480)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 19, 19, 480)  12000       block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 19, 19, 480)  1920        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 19, 19, 480)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 480)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 19, 19, 480)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 19, 19, 80)   38400       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 19, 19, 80)   320         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 19, 19, 80)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 19, 19, 80)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 19, 19, 480)  38400       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 19, 19, 480)  1920        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 19, 19, 480)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 19, 19, 480)  12000       block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 19, 19, 480)  1920        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 19, 19, 480)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 480)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 19, 19, 480)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 19, 19, 80)   38400       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 19, 19, 80)   320         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 19, 19, 80)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 19, 19, 80)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 19, 19, 480)  38400       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 19, 19, 480)  1920        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 19, 19, 480)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 19, 19, 480)  12000       block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 19, 19, 480)  1920        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 19, 19, 480)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 480)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 19, 19, 480)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 19, 19, 80)   38400       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 19, 19, 80)   320         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 19, 19, 80)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 19, 19, 80)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 19, 19, 480)  38400       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 19, 19, 480)  1920        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 19, 19, 480)  0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 19, 19, 480)  12000       block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 19, 19, 480)  1920        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 19, 19, 480)  0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 480)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 19, 19, 480)  0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# ...
# block6m_dwconv (DepthwiseConv2D (None, 5, 5, 2304)   57600       block6m_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6m_bn (BatchNormalization) (None, 5, 5, 2304)   9216        block6m_dwconv[0][0]
# __________________________________________________________________________________________________
# block6m_activation (Activation) (None, 5, 5, 2304)   0           block6m_bn[0][0]
# __________________________________________________________________________________________________
# block6m_se_squeeze (GlobalAvera (None, 2304)         0           block6m_activation[0][0]
# __________________________________________________________________________________________________
# block6m_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block6m_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6m_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block6m_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6m_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block6m_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6m_se_excite (Multiply)    (None, 5, 5, 2304)   0           block6m_activation[0][0]
#                                                                  block6m_se_expand[0][0]
# __________________________________________________________________________________________________
# block6m_project_conv (Conv2D)   (None, 5, 5, 384)    884736      block6m_se_excite[0][0]
# __________________________________________________________________________________________________
# block6m_project_bn (BatchNormal (None, 5, 5, 384)    1536        block6m_project_conv[0][0]
# __________________________________________________________________________________________________
# block6m_drop (Dropout)          (None, 5, 5, 384)    0           block6m_project_bn[0][0]
# __________________________________________________________________________________________________
# block6m_add (Add)               (None, 5, 5, 384)    0           block6m_drop[0][0]
#                                                                  block6l_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 5, 5, 2304)   884736      block6m_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 5, 5, 2304)   9216        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 5, 5, 2304)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 5, 5, 2304)   20736       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 5, 5, 2304)   9216        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 5, 5, 2304)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 2304)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 5, 5, 2304)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 5, 5, 640)    1474560     block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 5, 5, 640)    2560        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 5, 5, 3840)   2457600     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 5, 5, 3840)   15360       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 5, 5, 3840)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 5, 5, 3840)   34560       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 5, 5, 3840)   15360       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 5, 5, 3840)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 3840)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 5, 5, 3840)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 5, 5, 640)    2457600     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 5, 5, 640)    2560        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 5, 5, 640)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 5, 5, 640)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_expand_conv (Conv2D)    (None, 5, 5, 3840)   2457600     block7b_add[0][0]
# __________________________________________________________________________________________________
# block7c_expand_bn (BatchNormali (None, 5, 5, 3840)   15360       block7c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7c_expand_activation (Acti (None, 5, 5, 3840)   0           block7c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 5, 5, 3840)   34560       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 5, 5, 3840)   15360       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 5, 5, 3840)   0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3840)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 5, 5, 3840)   0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 5, 5, 640)    2457600     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 5, 5, 640)    2560        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (Dropout)          (None, 5, 5, 640)    0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 5, 5, 640)    0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_conv (Conv2D)    (None, 5, 5, 3840)   2457600     block7c_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_bn (BatchNormali (None, 5, 5, 3840)   15360       block7d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7d_expand_activation (Acti (None, 5, 5, 3840)   0           block7d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7d_dwconv (DepthwiseConv2D (None, 5, 5, 3840)   34560       block7d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7d_bn (BatchNormalization) (None, 5, 5, 3840)   15360       block7d_dwconv[0][0]
# __________________________________________________________________________________________________
# block7d_activation (Activation) (None, 5, 5, 3840)   0           block7d_bn[0][0]
# __________________________________________________________________________________________________
# block7d_se_squeeze (GlobalAvera (None, 3840)         0           block7d_activation[0][0]
# __________________________________________________________________________________________________
# block7d_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7d_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7d_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7d_se_excite (Multiply)    (None, 5, 5, 3840)   0           block7d_activation[0][0]
#                                                                  block7d_se_expand[0][0]
# __________________________________________________________________________________________________
# block7d_project_conv (Conv2D)   (None, 5, 5, 640)    2457600     block7d_se_excite[0][0]
# __________________________________________________________________________________________________
# block7d_project_bn (BatchNormal (None, 5, 5, 640)    2560        block7d_project_conv[0][0]
# __________________________________________________________________________________________________
# block7d_drop (Dropout)          (None, 5, 5, 640)    0           block7d_project_bn[0][0]
# __________________________________________________________________________________________________
# block7d_add (Add)               (None, 5, 5, 640)    0           block7d_drop[0][0]
#                                                                  block7c_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 5, 5, 2560)   1638400     block7d_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 5, 5, 2560)   10240       top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 5, 5, 2560)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2560)         0           top_activation[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            7683        global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 64,105,370
# Trainable params: 63,794,643
# Non-trainable params: 310,727
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import optimizers

# %%
#optim = optimizers.Nadam(lr=0.001,clipnorm=1)
optim = optimizers.Nadam(lr=0.00001)

# %%
from tensorflow.keras import backend as K
def F1_score(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (predicted_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    recall = recall(y_true, y_pred)
    precision = precision(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# %%
Model.compile(loss='categorical_crossentropy', optimizer=optim, metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_path = './dataset/train'
valid_path = './dataset/validation'
test_path = './dataset/test'
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True,vertical_flip=True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (input_size, input_size),
                                                 batch_size = 4,
                                                 class_mode = 'categorical')
print(training_set.class_indices)
test_set = test_datagen.flow_from_directory(valid_path,
                                            target_size = (input_size, input_size),
                                            batch_size = 4,
                                            class_mode = 'categorical')
print(test_set.class_indices)
# Out:
# Found 168 images belonging to 3 classes.
# {'Close': 0, 'Open': 1, 'Unknown': 2}
# Found 52 images belonging to 3 classes.
# {'Close': 0, 'Open': 1, 'Unknown': 2}

# %%
checkpoint = keras.callbacks.ModelCheckpoint('best_model_B7_v3.h5', monitor="val_loss", verbose=1,
                                             save_best_only=True, save_weights_only=False, mode="min")
es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self,epoch,logs={}):
        if (logs.get('accuracy')>0.96):
            print("Reached 96% accuracy so cancelling training!")
            self.model.stop_training=True
callbacks = myCallback()

# %%
import os
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"] = "2"
history = Model.fit( training_set, validation_data=test_set, epochs=100, 
                    steps_per_epoch=len(training_set), validation_steps=len(test_set),
                   callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 42/42 [==============================] - ETA: 0s - loss: 1.0594 - accuracy: 0.4762
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Epoch 00001: val_loss improved from inf to 1.10631, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 33s 789ms/step - loss: 1.0594 - accuracy: 0.4762 - val_loss: 1.1063 - val_accuracy: 0.4038
# Epoch 2/100
# 42/42 [==============================] - ETA: 0s - loss: 0.9417 - accuracy: 0.6548
# Epoch 00002: val_loss improved from 1.10631 to 1.10628, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 28s 668ms/step - loss: 0.9417 - accuracy: 0.6548 - val_loss: 1.1063 - val_accuracy: 0.4038
# Epoch 3/100
# 42/42 [==============================] - ETA: 0s - loss: 0.8348 - accuracy: 0.7619
# Epoch 00003: val_loss improved from 1.10628 to 1.10309, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 29s 684ms/step - loss: 0.8348 - accuracy: 0.7619 - val_loss: 1.1031 - val_accuracy: 0.4038
# Epoch 4/100
# 42/42 [==============================] - ETA: 0s - loss: 0.7783 - accuracy: 0.7857
# Epoch 00004: val_loss did not improve from 1.10309
# 42/42 [==============================] - 25s 591ms/step - loss: 0.7783 - accuracy: 0.7857 - val_loss: 1.1372 - val_accuracy: 0.4038
# Epoch 5/100
# 42/42 [==============================] - ETA: 0s - loss: 0.7341 - accuracy: 0.7500
# Epoch 00005: val_loss did not improve from 1.10309
# 42/42 [==============================] - 25s 588ms/step - loss: 0.7341 - accuracy: 0.7500 - val_loss: 1.1787 - val_accuracy: 0.4038
# Epoch 6/100
# 42/42 [==============================] - ETA: 0s - loss: 0.6758 - accuracy: 0.7619
# Epoch 00006: val_loss did not improve from 1.10309
# 42/42 [==============================] - 25s 586ms/step - loss: 0.6758 - accuracy: 0.7619 - val_loss: 1.2248 - val_accuracy: 0.2692
# Epoch 7/100
# 42/42 [==============================] - ETA: 0s - loss: 0.6029 - accuracy: 0.8274
# Epoch 00007: val_loss did not improve from 1.10309
# 42/42 [==============================] - 25s 599ms/step - loss: 0.6029 - accuracy: 0.8274 - val_loss: 1.2205 - val_accuracy: 0.2308
# Epoch 8/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5425 - accuracy: 0.8512
# Epoch 00008: val_loss did not improve from 1.10309
# 42/42 [==============================] - 25s 590ms/step - loss: 0.5425 - accuracy: 0.8512 - val_loss: 1.2806 - val_accuracy: 0.1154
# Epoch 9/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5439 - accuracy: 0.7976
# Epoch 00009: val_loss did not improve from 1.10309
# 42/42 [==============================] - 25s 600ms/step - loss: 0.5439 - accuracy: 0.7976 - val_loss: 1.2804 - val_accuracy: 0.1538
# Epoch 10/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4785 - accuracy: 0.8690
# Epoch 00010: val_loss did not improve from 1.10309
# 42/42 [==============================] - 25s 594ms/step - loss: 0.4785 - accuracy: 0.8690 - val_loss: 1.1463 - val_accuracy: 0.2692
# Epoch 11/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5144 - accuracy: 0.8274
# Epoch 00011: val_loss improved from 1.10309 to 1.02796, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 29s 696ms/step - loss: 0.5144 - accuracy: 0.8274 - val_loss: 1.0280 - val_accuracy: 0.4038
# Epoch 12/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4571 - accuracy: 0.8571
# Epoch 00012: val_loss improved from 1.02796 to 0.96100, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 710ms/step - loss: 0.4571 - accuracy: 0.8571 - val_loss: 0.9610 - val_accuracy: 0.6154
# Epoch 13/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4136 - accuracy: 0.8393
# Epoch 00013: val_loss improved from 0.96100 to 0.91108, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 710ms/step - loss: 0.4136 - accuracy: 0.8393 - val_loss: 0.9111 - val_accuracy: 0.6346
# Epoch 14/100
# 42/42 [==============================] - ETA: 0s - loss: 0.3916 - accuracy: 0.8631
# Epoch 00014: val_loss improved from 0.91108 to 0.88950, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 29s 692ms/step - loss: 0.3916 - accuracy: 0.8631 - val_loss: 0.8895 - val_accuracy: 0.6538
# Epoch 15/100
# 42/42 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.9107
# Epoch 00015: val_loss improved from 0.88950 to 0.82175, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 712ms/step - loss: 0.3247 - accuracy: 0.9107 - val_loss: 0.8218 - val_accuracy: 0.7115
# Epoch 16/100
# 42/42 [==============================] - ETA: 0s - loss: 0.3664 - accuracy: 0.8810
# Epoch 00016: val_loss improved from 0.82175 to 0.73546, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 714ms/step - loss: 0.3664 - accuracy: 0.8810 - val_loss: 0.7355 - val_accuracy: 0.7692
# Epoch 17/100
# 42/42 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.8810
# Epoch 00017: val_loss improved from 0.73546 to 0.63392, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 710ms/step - loss: 0.3753 - accuracy: 0.8810 - val_loss: 0.6339 - val_accuracy: 0.7500
# Epoch 18/100
# 42/42 [==============================] - ETA: 0s - loss: 0.3401 - accuracy: 0.8810
# Epoch 00018: val_loss improved from 0.63392 to 0.59404, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 721ms/step - loss: 0.3401 - accuracy: 0.8810 - val_loss: 0.5940 - val_accuracy: 0.7885
# Epoch 19/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.8929
# Epoch 00019: val_loss improved from 0.59404 to 0.46903, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 713ms/step - loss: 0.2898 - accuracy: 0.8929 - val_loss: 0.4690 - val_accuracy: 0.8654
# Epoch 20/100
# 42/42 [==============================] - ETA: 0s - loss: 0.3556 - accuracy: 0.8869
# Epoch 00020: val_loss improved from 0.46903 to 0.44616, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 713ms/step - loss: 0.3556 - accuracy: 0.8869 - val_loss: 0.4462 - val_accuracy: 0.9231
# Epoch 21/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.8929
# Epoch 00021: val_loss improved from 0.44616 to 0.40102, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 733ms/step - loss: 0.2864 - accuracy: 0.8929 - val_loss: 0.4010 - val_accuracy: 0.8846
# Epoch 22/100
# 42/42 [==============================] - ETA: 0s - loss: 0.3028 - accuracy: 0.9048
# Epoch 00022: val_loss improved from 0.40102 to 0.37050, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 716ms/step - loss: 0.3028 - accuracy: 0.9048 - val_loss: 0.3705 - val_accuracy: 0.8462
# Epoch 23/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.8869
# Epoch 00023: val_loss improved from 0.37050 to 0.36210, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 725ms/step - loss: 0.2824 - accuracy: 0.8869 - val_loss: 0.3621 - val_accuracy: 0.8846
# Epoch 24/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9762
# Epoch 00024: val_loss did not improve from 0.36210
# 42/42 [==============================] - 26s 625ms/step - loss: 0.1387 - accuracy: 0.9762 - val_loss: 0.3663 - val_accuracy: 0.8654
# Epoch 25/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9464
# Epoch 00025: val_loss did not improve from 0.36210
# 42/42 [==============================] - 26s 620ms/step - loss: 0.1842 - accuracy: 0.9464 - val_loss: 0.3786 - val_accuracy: 0.8846
# Epoch 26/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.9107
# Epoch 00026: val_loss did not improve from 0.36210
# 42/42 [==============================] - 26s 625ms/step - loss: 0.2581 - accuracy: 0.9107 - val_loss: 0.4026 - val_accuracy: 0.8462
# Epoch 27/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.9107
# Epoch 00027: val_loss did not improve from 0.36210
# 42/42 [==============================] - 27s 636ms/step - loss: 0.2450 - accuracy: 0.9107 - val_loss: 0.4112 - val_accuracy: 0.8654
# Epoch 28/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2402 - accuracy: 0.9226
# Epoch 00028: val_loss improved from 0.36210 to 0.35700, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 720ms/step - loss: 0.2402 - accuracy: 0.9226 - val_loss: 0.3570 - val_accuracy: 0.9231
# Epoch 29/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9583
# Epoch 00029: val_loss improved from 0.35700 to 0.32403, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 730ms/step - loss: 0.1744 - accuracy: 0.9583 - val_loss: 0.3240 - val_accuracy: 0.9038
# Epoch 30/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1805 - accuracy: 0.9345
# Epoch 00030: val_loss did not improve from 0.32403
# 42/42 [==============================] - 27s 640ms/step - loss: 0.1805 - accuracy: 0.9345 - val_loss: 0.3258 - val_accuracy: 0.8846
# Epoch 31/100
# 42/42 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.8929
# Epoch 00031: val_loss did not improve from 0.32403
# 42/42 [==============================] - 27s 635ms/step - loss: 0.3023 - accuracy: 0.8929 - val_loss: 0.3279 - val_accuracy: 0.9038
# Epoch 32/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1765 - accuracy: 0.9405
# Epoch 00032: val_loss improved from 0.32403 to 0.32009, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 740ms/step - loss: 0.1765 - accuracy: 0.9405 - val_loss: 0.3201 - val_accuracy: 0.9231
# Epoch 33/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9583
# Epoch 00033: val_loss improved from 0.32009 to 0.31797, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 733ms/step - loss: 0.1300 - accuracy: 0.9583 - val_loss: 0.3180 - val_accuracy: 0.9231
# Epoch 34/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.9048
# Epoch 00034: val_loss improved from 0.31797 to 0.30915, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 728ms/step - loss: 0.2677 - accuracy: 0.9048 - val_loss: 0.3092 - val_accuracy: 0.9038
# Epoch 35/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.9583
# Epoch 00035: val_loss did not improve from 0.30915
# 42/42 [==============================] - 26s 630ms/step - loss: 0.1474 - accuracy: 0.9583 - val_loss: 0.3365 - val_accuracy: 0.8846
# Epoch 36/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2030 - accuracy: 0.9524
# Epoch 00036: val_loss improved from 0.30915 to 0.30870, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 746ms/step - loss: 0.2030 - accuracy: 0.9524 - val_loss: 0.3087 - val_accuracy: 0.8846
# Epoch 37/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9345
# Epoch 00037: val_loss improved from 0.30870 to 0.30344, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 721ms/step - loss: 0.1929 - accuracy: 0.9345 - val_loss: 0.3034 - val_accuracy: 0.9038
# Epoch 38/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 0.9702
# Epoch 00038: val_loss improved from 0.30344 to 0.29399, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 30s 723ms/step - loss: 0.1227 - accuracy: 0.9702 - val_loss: 0.2940 - val_accuracy: 0.9231
# Epoch 39/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9286
# Epoch 00039: val_loss did not improve from 0.29399
# 42/42 [==============================] - 27s 639ms/step - loss: 0.1876 - accuracy: 0.9286 - val_loss: 0.3267 - val_accuracy: 0.9231
# Epoch 40/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9821
# Epoch 00040: val_loss did not improve from 0.29399
# 42/42 [==============================] - 27s 642ms/step - loss: 0.1073 - accuracy: 0.9821 - val_loss: 0.3142 - val_accuracy: 0.9231
# Epoch 41/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9524
# Epoch 00041: val_loss did not improve from 0.29399
# 42/42 [==============================] - 26s 628ms/step - loss: 0.1556 - accuracy: 0.9524 - val_loss: 0.3019 - val_accuracy: 0.9231
# Epoch 42/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9405
# Epoch 00042: val_loss improved from 0.29399 to 0.28919, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 741ms/step - loss: 0.1976 - accuracy: 0.9405 - val_loss: 0.2892 - val_accuracy: 0.9231
# Epoch 43/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1282 - accuracy: 0.9464
# Epoch 00043: val_loss did not improve from 0.28919
# 42/42 [==============================] - 27s 641ms/step - loss: 0.1282 - accuracy: 0.9464 - val_loss: 0.3055 - val_accuracy: 0.9038
# Epoch 44/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9226
# Epoch 00044: val_loss did not improve from 0.28919
# 42/42 [==============================] - 27s 641ms/step - loss: 0.2184 - accuracy: 0.9226 - val_loss: 0.3311 - val_accuracy: 0.9231
# Epoch 45/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.9643
# Epoch 00045: val_loss did not improve from 0.28919
# 42/42 [==============================] - 27s 635ms/step - loss: 0.1366 - accuracy: 0.9643 - val_loss: 0.3103 - val_accuracy: 0.9231
# Epoch 46/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0959 - accuracy: 0.9762
# Epoch 00046: val_loss did not improve from 0.28919
# 42/42 [==============================] - 27s 632ms/step - loss: 0.0959 - accuracy: 0.9762 - val_loss: 0.2953 - val_accuracy: 0.9423
# Epoch 47/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1278 - accuracy: 0.9702
# Epoch 00047: val_loss did not improve from 0.28919
# 42/42 [==============================] - 26s 622ms/step - loss: 0.1278 - accuracy: 0.9702 - val_loss: 0.3058 - val_accuracy: 0.9231
# Epoch 48/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9643
# Epoch 00048: val_loss improved from 0.28919 to 0.25992, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 739ms/step - loss: 0.1274 - accuracy: 0.9643 - val_loss: 0.2599 - val_accuracy: 0.9423
# Epoch 49/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.9464
# Epoch 00049: val_loss did not improve from 0.25992
# 42/42 [==============================] - 27s 645ms/step - loss: 0.1601 - accuracy: 0.9464 - val_loss: 0.2784 - val_accuracy: 0.9231
# Epoch 50/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1512 - accuracy: 0.9524
# Epoch 00050: val_loss did not improve from 0.25992
# 42/42 [==============================] - 27s 632ms/step - loss: 0.1512 - accuracy: 0.9524 - val_loss: 0.2794 - val_accuracy: 0.9423
# Epoch 51/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2212 - accuracy: 0.9167
# Epoch 00051: val_loss did not improve from 0.25992
# 42/42 [==============================] - 27s 644ms/step - loss: 0.2212 - accuracy: 0.9167 - val_loss: 0.2753 - val_accuracy: 0.9231
# Epoch 52/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9643
# Epoch 00052: val_loss did not improve from 0.25992
# 42/42 [==============================] - 27s 634ms/step - loss: 0.1028 - accuracy: 0.9643 - val_loss: 0.2969 - val_accuracy: 0.9231
# Epoch 53/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9464
# Epoch 00053: val_loss did not improve from 0.25992
# 42/42 [==============================] - 26s 629ms/step - loss: 0.1312 - accuracy: 0.9464 - val_loss: 0.2623 - val_accuracy: 0.9423
# Epoch 54/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9762
# Epoch 00054: val_loss did not improve from 0.25992
# 42/42 [==============================] - 27s 631ms/step - loss: 0.0962 - accuracy: 0.9762 - val_loss: 0.2655 - val_accuracy: 0.9423
# Epoch 55/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1648 - accuracy: 0.
saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 749ms/step - loss: 0.0339 - accuracy: 0.9940 - val_loss: 0.2469 - val_accuracy: 0.9615
# Epoch 90/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9821
# Epoch 00090: val_loss improved from 0.24691 to 0.24604, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 32s 753ms/step - loss: 0.0584 - accuracy: 0.9821 - val_loss: 0.2460 - val_accuracy: 0.9423
# Epoch 91/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9762
# Epoch 00091: val_loss did not improve from 0.24604
# 42/42 [==============================] - 27s 642ms/step - loss: 0.0685 - accuracy: 0.9762 - val_loss: 0.2629 - val_accuracy: 0.9423
# Epoch 92/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9762
# Epoch 00092: val_loss did not improve from 0.24604
# 42/42 [==============================] - 27s 654ms/step - loss: 0.0737 - accuracy: 0.9762 - val_loss: 0.2839 - val_accuracy: 0.9423
# Epoch 93/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9940
# Epoch 00093: val_loss did not improve from 0.24604
# 42/42 [==============================] - 27s 649ms/step - loss: 0.0367 - accuracy: 0.9940 - val_loss: 0.2746 - val_accuracy: 0.9423
# Epoch 94/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9881
# Epoch 00094: val_loss did not improve from 0.24604
# 42/42 [==============================] - 27s 652ms/step - loss: 0.0329 - accuracy: 0.9881 - val_loss: 0.2720 - val_accuracy: 0.9231
# Epoch 95/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9762
# Epoch 00095: val_loss did not improve from 0.24604
# 42/42 [==============================] - 27s 644ms/step - loss: 0.0688 - accuracy: 0.9762 - val_loss: 0.2766 - val_accuracy: 0.9423
# Epoch 96/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9702
# Epoch 00096: val_loss did not improve from 0.24604
# 42/42 [==============================] - 28s 660ms/step - loss: 0.0903 - accuracy: 0.9702 - val_loss: 0.2958 - val_accuracy: 0.9231
# Epoch 97/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 1.0000
# Epoch 00097: val_loss did not improve from 0.24604
# 42/42 [==============================] - 27s 654ms/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 0.2687 - val_accuracy: 0.9231
# Epoch 98/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9762
# Epoch 00098: val_loss did not improve from 0.24604
# 42/42 [==============================] - 27s 636ms/step - loss: 0.0976 - accuracy: 0.9762 - val_loss: 0.2825 - val_accuracy: 0.9231
# Epoch 99/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9821
# Epoch 00099: val_loss did not improve from 0.24604
# 42/42 [==============================] - 27s 641ms/step - loss: 0.0557 - accuracy: 0.9821 - val_loss: 0.2842 - val_accuracy: 0.9231
# Epoch 100/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9821
# Epoch 00100: val_loss improved from 0.24604 to 0.23852, saving model to best_model_B7_v3.h5
# 42/42 [==============================] - 31s 747ms/step - loss: 0.0730 - accuracy: 0.9821 - val_loss: 0.2385 - val_accuracy: 0.9423

# %%
Model.save_weights('model_weights.h5')
Model.save('model.h5')
print("model saved")
# Out:
# model saved

# %%
# loss
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
# plt.savefig('LossVal_loss')

# accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
# plt.savefig('AccVal_acc')

# F1 score
plt.plot(history.history['F1_score'], label='train F1')
plt.plot(history.history['val_F1_score'], label='val F1')
plt.legend()
plt.show()
# plt.savefig('F1Val_F1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-8fcad0ed6eb9> in <module>()
#      15
#      16 # F1 score
# ---> 17 plt.plot(history.history['F1_score'], label='train F1')
#      18 plt.plot(history.history['val_F1_score'], label='val F1')
#      19 plt.legend()
#
# KeyError: 'F1_score'

# %%
#prediction
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
loaded_model = load_model('best_model_B7_v3.h5')
path="c_3.png"
img_pred = image.load_img(path, target_size=(150, 150))
img_pred = image.img_to_array(img_pred)
img_pred = np.expand_dims(img_pred, axis=0)
#images = np.vstack([img_pred])
rslt = loaded_model.predict(img_pred)
print(rslt)
print(np.argmax(rslt))
if np.argmax(rslt) == 0:
  print("Close")
if np.argmax(rslt) == 1:
  print("Open")
else:
  print("Unknown")
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa375ab41e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[9.9928135e-01 7.1864791e-04 2.5122374e-10]]
# 0
# Close
# Unknown
